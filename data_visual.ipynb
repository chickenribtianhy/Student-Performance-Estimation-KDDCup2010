# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
train_data = 'data/train.csv'
test_data = 'data/test.csv'

# Read the data
train = pd.read_csv(train_data, sep='\t')
test = pd.read_csv(test_data, sep='\t')

# %%
columns = ['Anon Student Id','Problem Name','Problem View', 'Step Name', 'Step Start Time',
        'First Transaction Time', 'Correct Transaction Time','Step End Time','Step Duration (sec)', 'Correct Step Duration (sec)',
        'Error Step Duration (sec)','Correct First Attempt', 'Incorrects','Hints', 'Corrects', 'KC(Default)', 'Opportunity(Default)']
data_type = {}
for col in train.columns:
    data_type[col] = train[col].dtype

num_of_students = len(np.unique(train['Anon Student Id']))
num_of_steps = len(np.unique(train[['Problem Name','Step Name']]))

# %%
visual_1 = train['Correct Step Duration (sec)']
print(visual_1.describe())
hist = plt.hist(np.array(visual_1.dropna()),bins=100,density=True,log=False,range=(0,100))
plt.xlabel('Correct Step Duration (sec)')
plt.ylabel('Fraction')
plt.show()
# Out:
# count    181599.000000
# mean         17.924024
# std          35.179534
# min           0.000000
# 25%           5.000000
# 50%           8.000000
# 75%          17.000000
# max        1067.000000
# Name: Correct Step Duration (sec), dtype: float64

# %%
visual_2 = train['Error Step Duration (sec)']
print(visual_2.describe())
hist = plt.hist(np.array(visual_2.dropna()),bins=200,density=True,log=False,range=(0,200))
plt.xlabel('Error Step Duration (sec)')
plt.ylabel('Fraction')
plt.show()
# Out:
# count    50853.000000
# mean        60.547204
# std         89.287960
# min          0.000000
# 25%         16.000000
# 50%         32.000000
# 75%         67.000000
# max       1888.000000
# Name: Error Step Duration (sec), dtype: float64

# %%
visual_3 = train['Correct First Attempt']
print(visual_3.describe())
hist = plt.hist(np.array(visual_3.dropna()),bins=2,density=True,log=False,range=(0,2))
plt.xlabel('Correct First Attempt')
plt.ylabel('Fraction')
plt.show()
# Out:
# count    232744.000000
# mean          0.780935
# std           0.413613
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: Correct First Attempt, dtype: float64

# %%
visual_4 = train['Problem View']
print(visual_4.describe())
hist = plt.hist(np.array(visual_4.dropna()),bins=15,density=True,log=False,range=(0,22))
plt.xlabel('Problem View')
plt.ylabel('Fraction')
plt.show()
# Out:
# count    232744.000000
# mean          1.602838
# std           1.515546
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max          21.000000
# Name: Problem View, dtype: float64

# %%
visual_5 = train['Corrects']
print(visual_5.describe())
hist = plt.hist(np.array(visual_5.dropna()),bins=10,density=True,log=False,range=(0,10))
plt.xlabel('Corrects')
plt.ylabel('Fraction')
plt.show()
# Out:
# count    232744.000000
# mean          1.172636
# std           0.797579
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          73.000000
# Name: Corrects, dtype: float64

# %%
visual_6 = train['Incorrects']
print(visual_6.describe())
hist = plt.hist(np.array(visual_6.dropna()),bins=10,density=True,log=False,range=(0,10))
plt.xlabel('Incorrects')
plt.ylabel('Fraction')
plt.show()
# Out:
# count    232744.000000
# mean          0.475217
# std           1.932919
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         175.000000
# Name: Incorrects, dtype: float64

# %%
visual_7 = train['Hints']
print(visual_7.describe())
hist = plt.hist(np.array(visual_7.dropna()),bins=10,density=True,log=False,range=(0,10))
plt.xlabel('Hints')
plt.ylabel('Fraction')
plt.show()
# Out:
# count    232744.000000
# mean          0.259985
# std           1.114299
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          74.000000
# Name: Hints, dtype: float64
